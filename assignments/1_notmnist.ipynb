# %% [markdown]
# Deep Learning
# =============
#
# Assignment 1
# ------------
#
# The objective of this assignment is to learn about simple data curation practices, and familiarize you with some of the data we'll be reusing later.
#
# This notebook uses the [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) dataset to be used with python experiments. This dataset is designed to look like the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, while looking a little more like real data: it's a harder task, and the data is a lot less 'clean' than MNIST.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %% [markdown]
# First, we'll download the dataset to our local machine. The data consists of characters rendered in a variety of fonts on a 28x28 image. The labels are limited to 'A' through 'J' (10 classes). The training set has about 500k and the testset 19000 labelled examples. Given these sizes, it should be possible to train models quickly on any machine.

# %%
url = 'http://commondatastorage.googleapis.com/books1000/'
last_percent_reported = None

def download_progress_hook(count, blockSize, totalSize):
  """A hook to report the progress of a download. This is mostly intended for users with
  slow internet connections. Reports every 1% change in download progress.
  """
  global last_percent_reported
  percent = int(count * blockSize * 100 / totalSize)

  if last_percent_reported != percent:
    if percent % 5 == 0:
      sys.stdout.write("%s%%" % percent)
      sys.stdout.flush()
    else:
      sys.stdout.write(".")
      sys.stdout.flush()
      
    last_percent_reported = percent
        
def maybe_download(filename, expected_bytes, force=False):
  """Download a file if not present, and make sure it's the right size."""
  if force or not os.path.exists(filename):
    print('Attempting to download:', filename) 
    filename, _ = urlretrieve(url + filename, filename, reporthook=download_progress_hook)
    print('\nDownload Complete!')
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

train_filename = maybe_download('notMNIST_large.tar.gz', 247336696)
test_filename = maybe_download('notMNIST_small.tar.gz', 8458043)
# Out:
# Found and verified notMNIST_large.tar.gz
# Found and verified notMNIST_small.tar.gz

# %% [markdown]
# Extract the dataset from the compressed .tar.gz file.
# This should give you a set of directories, labelled A through J.

# %%
num_classes = 10
np.random.seed(133)

def maybe_extract(filename, force=False):
  root = os.path.splitext(os.path.splitext(filename)[0])[0]  # remove .tar.gz
  if os.path.isdir(root) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping extraction of %s.' % (root, filename))
  else:
    print('Extracting data for %s. This may take a while. Please wait.' % root)
    tar = tarfile.open(filename)
    sys.stdout.flush()
    tar.extractall()
    tar.close()
  data_folders = [
    os.path.join(root, d) for d in sorted(os.listdir(root))
    if os.path.isdir(os.path.join(root, d))]
  if len(data_folders) != num_classes:
    raise Exception(
      'Expected %d folders, one per class. Found %d instead.' % (
        num_classes, len(data_folders)))
  print(data_folders)
  return data_folders
  
train_folders = maybe_extract(train_filename)
test_folders = maybe_extract(test_filename)
# Out:
# notMNIST_large already present - Skipping extraction of notMNIST_large.tar.gz.
# ['notMNIST_large/A', 'notMNIST_large/B', 'notMNIST_large/C', 'notMNIST_large/D', 'notMNIST_large/E', 'notMNIST_large/F', 'notMNIST_large/G', 'notMNIST_large/H', 'notMNIST_large/I', 'notMNIST_large/J']
# notMNIST_small already present - Skipping extraction of notMNIST_small.tar.gz.
# ['notMNIST_small/A', 'notMNIST_small/B', 'notMNIST_small/C', 'notMNIST_small/D', 'notMNIST_small/E', 'notMNIST_small/F', 'notMNIST_small/G', 'notMNIST_small/H', 'notMNIST_small/I', 'notMNIST_small/J']

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Let's take a peek at some of the data to make sure it looks sensible. Each exemplar should be an image of a character A through J rendered in a different font. Display a sample of the images that we just downloaded. Hint: you can use the package IPython.display.
#
# ---

# %%
from IPython.display import display, Image
display(Image(filename="notMNIST_small/A/Q0NXaWxkV29yZHMtQm9sZEl0YWxpYy50dGY=.png"))

# %% [markdown]
# Now let's load the data in a more manageable format. Since, depending on your computer setup you might not be able to fit it all in memory, we'll load each class into a separate dataset, store them on disk and curate them independently. Later we'll merge them into a single dataset of manageable size.
#
# We'll convert the entire dataset into a 3D array (image index, x, y) of floating point values, normalized to have approximately zero mean and standard deviation ~0.5 to make training easier down the road.
#
# A few images might not be readable, we'll just skip them.

# %%
image_size = 28  # Pixel width and height.
pixel_depth = 255.0  # Number of levels per pixel.

def load_letter(folder, min_num_images):
  """Load the data for a single letter label."""
  image_files = os.listdir(folder)
  dataset = np.ndarray(shape=(len(image_files), image_size, image_size),
                         dtype=np.float32)
  print(folder)
  num_images = 0
  for image in image_files:
    image_file = os.path.join(folder, image)
    try:
      image_data = (ndimage.imread(image_file).astype(float) - 
                    pixel_depth / 2) / pixel_depth
      if image_data.shape != (image_size, image_size):
        raise Exception('Unexpected image shape: %s' % str(image_data.shape))
      dataset[num_images, :, :] = image_data
      num_images = num_images + 1
    except IOError as e:
      print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')
    
  dataset = dataset[0:num_images, :, :]
  if num_images < min_num_images:
    raise Exception('Many fewer images than expected: %d < %d' %
                    (num_images, min_num_images))
    
  print('Full dataset tensor:', dataset.shape)
  print('Mean:', np.mean(dataset))
  print('Standard deviation:', np.std(dataset))
  return dataset
        
def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_letter(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 45000)
test_datasets = maybe_pickle(test_folders, 1800)
# Out:
# notMNIST_large/A.pickle already present - Skipping pickling.
# notMNIST_large/B.pickle already present - Skipping pickling.
# notMNIST_large/C.pickle already present - Skipping pickling.
# notMNIST_large/D.pickle already present - Skipping pickling.
# notMNIST_large/E.pickle already present - Skipping pickling.
# notMNIST_large/F.pickle already present - Skipping pickling.
# notMNIST_large/G.pickle already present - Skipping pickling.
# notMNIST_large/H.pickle already present - Skipping pickling.
# notMNIST_large/I.pickle already present - Skipping pickling.
# notMNIST_large/J.pickle already present - Skipping pickling.
# notMNIST_small/A.pickle already present - Skipping pickling.
# notMNIST_small/B.pickle already present - Skipping pickling.
# notMNIST_small/C.pickle already present - Skipping pickling.
# notMNIST_small/D.pickle already present - Skipping pickling.
# notMNIST_small/E.pickle already present - Skipping pickling.
# notMNIST_small/F.pickle already present - Skipping pickling.
# notMNIST_small/G.pickle already present - Skipping pickling.
# notMNIST_small/H.pickle already present - Skipping pickling.
# notMNIST_small/I.pickle already present - Skipping pickling.
# notMNIST_small/J.pickle already present - Skipping pickling.

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Let's verify that the data still looks good. Displaying a sample of the labels and images from the ndarray. Hint: you can use matplotlib.pyplot.
#
# ---

# %%
# Select pickle file
pickle_file = train_datasets[0]  # letter A

with open(pickle_file, 'rb') as f:
    letter_set = pickle.load(f)
    sample_idx = np.random.randint(len(letter_set))
    
    # pick a random image
    sample_image = letter_set[sample_idx, :, :]
    
    # Show with Matplotlib
    plt.figure()
    plt.imshow(sample_image)
    plt.show()

# %% [markdown]
# ---
# Problem 3
# ---------
# Another check: we expect the data to be balanced across classes. Verify that.
#
# ---

# %%
# Goal: read every pickle file and check the number of images it
# contains. It should be exactly the same
for i in range(len(train_datasets)):
    pickle_file = train_datasets[i]
    
    with open(pickle_file, 'rb') as f:
        letter_set = pickle.load(f)
        print('Letter %c: %d' % (ord('A') + i, len(letter_set)))
# Out:
# Letter A: 52909
# Letter B: 52911
# Letter C: 52912
# Letter D: 52911
# Letter E: 52912
# Letter F: 52912
# Letter G: 52912
# Letter H: 52912
# Letter I: 52912
# Letter J: 52911

# %% [markdown]
# Merge and prune the training data as needed. Depending on your computer setup, you might not be able to fit it all in memory, and you can tune `train_size` as needed. The labels will be stored into a separate array of integers 0 through 9.
#
# Also create a validation dataset for hyperparameter tuning.

# %%
def make_arrays(nb_rows, img_size):
  if nb_rows:
    dataset = np.ndarray((nb_rows, img_size, img_size), dtype=np.float32)
    labels = np.ndarray(nb_rows, dtype=np.int32)
  else:
    dataset, labels = None, None
  return dataset, labels

def merge_datasets(pickle_files, train_size, valid_size=0):
  num_classes = len(pickle_files)
  valid_dataset, valid_labels = make_arrays(valid_size, image_size)
  train_dataset, train_labels = make_arrays(train_size, image_size)
  vsize_per_class = valid_size // num_classes
  tsize_per_class = train_size // num_classes
    
  start_v, start_t = 0, 0
  end_v, end_t = vsize_per_class, tsize_per_class
  end_l = vsize_per_class+tsize_per_class
  for label, pickle_file in enumerate(pickle_files):       
    try:
      with open(pickle_file, 'rb') as f:
        letter_set = pickle.load(f)
        # let's shuffle the letters to have random validation and training set
        np.random.shuffle(letter_set)
        if valid_dataset is not None:
          valid_letter = letter_set[:vsize_per_class, :, :]
          valid_dataset[start_v:end_v, :, :] = valid_letter
          valid_labels[start_v:end_v] = label
          start_v += vsize_per_class
          end_v += vsize_per_class
                    
        train_letter = letter_set[vsize_per_class:end_l, :, :]
        train_dataset[start_t:end_t, :, :] = train_letter
        train_labels[start_t:end_t] = label
        start_t += tsize_per_class
        end_t += tsize_per_class
    except Exception as e:
      print('Unable to process data from', pickle_file, ':', e)
      raise
    
  return valid_dataset, valid_labels, train_dataset, train_labels
            
            
train_size = 200000
valid_size = 10000
test_size = 10000

valid_dataset, valid_labels, train_dataset, train_labels = merge_datasets(
  train_datasets, train_size, valid_size)
_, _, test_dataset, test_labels = merge_datasets(test_datasets, test_size)

print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# Training: (200000, 28, 28) (200000,)
# Validation: (10000, 28, 28) (10000,)
# Testing: (10000, 28, 28) (10000,)

# %% [markdown]
# Next, we'll randomize the data. It's important to have the labels well shuffled for the training and test distributions to match.

# %%
def randomize(dataset, labels):
  permutation = np.random.permutation(labels.shape[0])
  shuffled_dataset = dataset[permutation,:,:]
  shuffled_labels = labels[permutation]
  return shuffled_dataset, shuffled_labels
train_dataset, train_labels = randomize(train_dataset, train_labels)
test_dataset, test_labels = randomize(test_dataset, test_labels)
valid_dataset, valid_labels = randomize(valid_dataset, valid_labels)

# %% [markdown]
# ---
# Problem 4
# ---------
# Convince yourself that the data is still good after shuffling!
#
# ---

# %%
# Display 3 images from train dataset and check they are suffled
img1 = train_dataset[0, :, :]
img2 = train_dataset[1, :, :]
img3 = train_dataset[2, :, :]

plt.figure()
plt.imshow(img1)
plt.show()

plt.figure()
plt.imshow(img2)
plt.show()

plt.figure()
plt.imshow(img3)
plt.show()

# %% [markdown]
# Finally, let's save the data for later reuse:

# %%
pickle_file = 'notMNIST.pickle'

try:
  f = open(pickle_file, 'wb')
  save = {
    'train_dataset': train_dataset,
    'train_labels': train_labels,
    'valid_dataset': valid_dataset,
    'valid_labels': valid_labels,
    'test_dataset': test_dataset,
    'test_labels': test_labels,
    }
  pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
  f.close()
except Exception as e:
  print('Unable to save data to', pickle_file, ':', e)
  raise

# %%
statinfo = os.stat(pickle_file)
print('Compressed pickle size:', statinfo.st_size)
# Out:
# Compressed pickle size: 690800441

# %% [markdown]
# ---
# Problem 5
# ---------
#
# By construction, this dataset might contain a lot of overlapping samples, including training data that's also contained in the validation and test set! Overlap between training and test can skew the results if you expect to use your model in an environment where there is never an overlap, but are actually ok if you expect to see training samples recur when you use it.
# Measure how much overlap there is between training, validation and test samples.
#
# Optional questions:
# - What about near duplicates between datasets? (images that are almost identical)
# - Create a sanitized validation and test set, and compare your accuracy on those in subsequent assignments.
# ---

# %%
# Check how many images from the validation and testing set
# are present in the training set
train_dataset.flags.writeable=False
test_dataset.flags.writeable=False
dup_table={}
for idx,img in enumerate(train_dataset):
    h = hash(img.data)
    if h in dup_table and (train_dataset[dup_table[h]].data == img.data):
       print('Duplicate image: %d matches %d' % (idx, dup_table[h]))
    dup_table[h] = idx
for idx,img in enumerate(test_dataset):
    h = hash(img.data)
    if h in dup_table and (train_dataset[dup_table[h]].data == img.data):
        print('Test image %d is in the training set' % idx)
# Out:
# Duplicate image: 115 matches 25
# Duplicate image: 260 matches 115
# Duplicate image: 303 matches 260
# Duplicate image: 332 matches 303
# Duplicate image: 343 matches 332
# Duplicate image: 410 matches 343
# Duplicate image: 526 matches 410
# Duplicate image: 543 matches 526
# Duplicate image: 1003 matches 543
# Duplicate image: 1071 matches 1003
# Duplicate image: 1196 matches 1071
# Duplicate image: 1275 matches 1196
# Duplicate image: 1284 matches 1275
# Duplicate image: 1321 matches 1284
# Duplicate image: 1338 matches 1321
# Duplicate image: 1494 matches 1338
# Duplicate image: 1528 matches 1494
# Duplicate image: 1633 matches 1528
# Duplicate image: 1700 matches 242
# Duplicate image: 1805 matches 1633
# Duplicate image: 1867 matches 1805
# Duplicate image: 1874 matches 1867
# Duplicate image: 1887 matches 1874
# Duplicate image: 1943 matches 1887
# Duplicate image: 1945 matches 1943
# Duplicate image: 1952 matches 1945
# Duplicate image: 1974 matches 1952
# Duplicate image: 2129 matches 1974
# Duplicate image: 2158 matches 2129
# Duplicate image: 2227 matches 2158
# Duplicate image: 2275 matches 2227
# Duplicate image: 2289 matches 2275
# Duplicate image: 2315 matches 2289
# Duplicate image: 2366 matches 2315
# Duplicate image: 2368 matches 2366
# Duplicate image: 2413 matches 1451
# Duplicate image: 2417 matches 2368
# Duplicate image: 2431 matches 2417
# Duplicate image: 2440 matches 2431
# Duplicate image: 2464 matches 217
# Duplicate image: 2477 matches 2440
# Duplicate image: 2512 matches 2477
# Duplicate image: 2531 matches 2512
# Duplicate image: 2733 matches 2531
# Duplicate image: 2943 matches 2733
# Duplicate image: 2985 matches 2943
# Duplicate image: 3086 matches 1586
# Duplicate image: 3136 matches 2985
# Duplicate image: 3142 matches 3136
# Duplicate image: 3213 matches 3142
# Duplicate image: 3268 matches 3213
# Duplicate image: 3312 matches 3268
# Duplicate image: 3462 matches 3312
# Duplicate image: 3510 matches 3462
# Duplicate image: 3610 matches 3184
# Duplicate image: 3678 matches 3510
# Duplicate image: 3751 matches 2413
# Duplicate image: 3960 matches 3678
# Duplicate image: 3994 matches 3960
# Duplicate image: 4029 matches 3994
# Duplicate image: 4038 matches 4029
# Duplicate image: 4045 matches 4038
# Duplicate image: 4101 matches 1529
# Duplicate image: 4153 matches 4045
# Duplicate image: 4349 matches 4153
# Duplicate image: 4358 matches 4349
# Duplicate image: 4424 matches 4358
# Duplicate image: 4481 matches 3751
# Duplicate image: 4525 matches 4424
# Duplicate image: 4563 matches 4525
# Duplicate image: 4635 matches 55
# Duplicate image: 4792 matches 4563
# Duplicate image: 4829 matches 4792
# Duplicate image: 4858 matches 4829
# Duplicate image: 5245 matches 4858
# Duplicate image: 5320 matches 5245
# Duplicate image: 5417 matches 3610
# Duplicate image: 5532 matches 5320
# Duplicate image: 5555 matches 5532
# Duplicate image: 5654 matches 5555
# Duplicate image: 5689 matches 3379
# Duplicate image: 5762 matches 5654
# Duplicate image: 5946 matches 2482
# Duplicate image: 5964 matches 5762
# Duplicate image: 6037 matches 5964
# Duplicate image: 6072 matches 5274
# Duplicate image: 6399 matches 779
# Duplicate image: 6431 matches 6037
# Duplicate image: 6519 matches 6431
# Duplicate image: 6529 matches 6519
# Duplicate image: 6538 matches 6529
# Duplicate image: 6580 matches 6538
# Duplicate image: 6627 matches 6580
# Duplicate image: 6738 matches 6627
# Duplicate image: 6792 matches 6738
# Duplicate image: 6794 matches 6792
# Duplicate image: 6827 matches 6794
# Duplicate image: 6834 matches 990
# Duplicate image: 6906 matches 6827
# Duplicate image: 7065 matches 589
# Duplicate image: 7373 matches 3256
# Duplicate image: 7432 matches 1023
# Duplicate image: 7485 matches 6906
# Duplicate image: 7547 matches 7485
# Duplicate image: 7592 matches 3736
# Duplicate image: 7596 matches 4481
# Duplicate image: 7655 matches 6930
# Duplicate image: 7684 matches 5398
# Duplicate image: 7731 matches 7547
# Duplicate image: 7784 matches 7731
# Duplicate image: 7883 matches 7784
# Duplicate image: 7951 matches 7883
# Duplicate image: 7994 matches 7951
# Duplicate image: 8125 matches 7994
# Duplicate image: 8136 matches 409
# Duplicate image: 8148 matches 8125
# Duplicate image: 8207 matches 8148
# Duplicate image: 8240 matches 8207
# Duplicate image: 8252 matches 8240
# Duplicate image: 8290 matches 8252
# Duplicate image: 8431 matches 2382
# Duplicate image: 8462 matches 8290
# Duplicate image: 8556 matches 5364
# Duplicate image: 8637 matches 8283
# Duplicate image: 8659 matches 7432
# Duplicate image: 8664 matches 8462
# Duplicate image: 8761 matches 8664
# Duplicate image: 8773 matches 8761
# Duplicate image: 8869 matches 1489
# Duplicate image: 8931 matches 8773
# Duplicate image: 8971 matches 5886
# Duplicate image: 8984 matches 8931
# Duplicate image: 9013 matches 8984
# Duplicate image: 9074 matches 9013
# Duplicate image: 9170 matches 7961
# Duplicate image: 9174 matches 9074
# Duplicate image: 9181 matches 9174
# Duplicate image: 9245 matches 9181
# Duplicate image: 9271 matches 9245
# Duplicate image: 9385 matches 6009
# Duplicate image: 9406 matches 5161
# Duplicate image: 9414 matches 9271
# Duplicate image: 9457 matches 9414
# Duplicate image: 9459 matches 9457
# Duplicate image: 9557 matches 9459
# Duplicate image: 9629 matches 9557
# Duplicate image: 9655 matches 5548
# Duplicate image: 9658 matches 9629
# Duplicate image: 9664 matches 3024
# Duplicate image: 9672 matches 9658
# Duplicate image: 9749 matches 1299
# Duplicate image: 9770 matches 5189
# Duplicate image: 9818 matches 9672
# Duplicate image: 9831 matches 9818
# Duplicate image: 9939 matches 9831
# Duplicate image: 9968 matches 9939
# Duplicate image: 10015 matches 6033
# Duplicate image: 10125 matches 9968
# Duplicate image: 10136 matches 7702
# Duplicate image: 10138 matches 10125
# Duplicate image: 10175 matches 4919
# Duplicate image: 10210 matches 10138
# Duplicate image: 10213 matches 4069
# Duplicate image: 10220 matches 6709
# Duplicate image: 10275 matches 6417
# Duplicate image: 10339 matches 10210
# Duplicate image: 10358 matches 557
# Duplicate image: 10399 matches 3086
# Duplicate image: 10416 matches 10162
# Duplicate image: 10510 matches 10339
# Duplicate image: 10527 matches 10510
# Duplicate image: 10608 matches 10527
# Duplicate image: 10619 matches 3400
# Duplicate image: 10722 matches 10608
# Duplicate image: 10755 matches 10722
# Duplicate image: 10771 matches 10399
# Duplicate image: 10804 matches 6834
# Duplicate image: 10854 matches 10755
# Duplicate image: 10881 matches 10854
# Duplicate image: 10913 matches 118
# Duplicate image: 10996 matches 10881
# Duplicate image: 11018 matches 10996
# Duplicate image: 11032 matches 11018
# Duplicate image: 11163 matches 4759
# Duplicate image: 11204 matches 9273
# Duplicate image: 11214 matches 11032
# Duplicate image: 11291 matches 5282
# Duplicate image: 11341 matches 8111
# Duplicate image: 11359 matches 11214
# Duplicate image: 11378 matches 11359
# Duplicate image: 11388 matches 11378
# Duplicate image: 11527 matches 11388
# Duplicate image: 11640 matches 10358
# Duplicate image: 11668 matches 1572
# Duplicate image: 11701 matches 7596
# Duplicate image: 11750 matches 5321
# Duplicate image: 11779 matches 4231
# Duplicate image: 11785 matches 11527
# Duplicate image: 11841 matches 8659
# Duplicate image: 11851 matches 11785
# Duplicate image: 11894 matches 221
# Duplicate image: 12045 matches 11841
# Duplicate image: 12162 matches 8797
# Duplicate image: 12265 matches 11245
# Duplicate image: 12335 matches 8348
# Duplicate image: 12526 matches 11851
# Duplicate image: 12532 matches 1442
# Duplicate image: 12537 matches 12526
# Duplicate image: 12540 matches 5499
# Duplicate image: 12554 matches 626
# Duplicate image: 12580 matches 5561
# Duplicate image: 12619 matches 12537
# Duplicate image: 12632 matches 6001
# Duplicate image: 12664 matches 9192
# Duplicate image: 12686 matches 8829
# Duplicate image: 12731 matches 12619
# Duplicate image: 12734 matches 1934
# Duplicate image: 12738 matches 12731
# Duplicate image: 12771 matches 12064
# Duplicate image: 12787 matches 12738
# Duplicate image: 12820 matches 4948
# Duplicate image: 12850 matches 12787
# Duplicate image: 12911 matches 12664
# Duplicate image: 13062 matches 9613
# Duplicate image: 13068 matches 1890
# Duplicate image: 13084 matches 12850
# Duplicate image: 13171 matches 13084
# Duplicate image: 13251 matches 6427
# Duplicate image: 13410 matches 12470
# Duplicate image: 13504 matches 5379
# Duplicate image: 13511 matches 12346
# Duplicate image: 13562 matches 1017
# Duplicate image: 13574 matches 13171
# Duplicate image: 13622 matches 13574
# Duplicate image: 13675 matches 13622
# Duplicate image: 13789 matches 8690
# Duplicate image: 13807 matches 11692
# Duplicate image: 13855 matches 13675
# Duplicate image: 13872 matches 13855
# Duplicate image: 13917 matches 10136
# Duplicate image: 13918 matches 13872
# Duplicate image: 13973 matches 13918
# Duplicate image: 14046 matches 13973
# Duplicate image: 14093 matches 404
# Duplicate image: 14096 matches 7466
# Duplicate image: 14111 matches 14046
# Duplicate image: 14112 matches 12407
# Duplicate image: 14154 matches 8942
# Duplicate image: 14208 matches 14111
# Duplicate image: 14265 matches 14208
# Duplicate image: 14287 matches 14265
# Duplicate image: 14410 matches 3493
# Duplicate image: 14451 matches 11570
# Duplicate image: 14543 matches 12820
# Duplicate image: 14583 matches 529
# Duplicate image: 14670 matches 14287
# Duplicate image: 14701 matches 3829
# Duplicate image: 14743 matches 14670
# Duplicate image: 14768 matches 14743
# Duplicate image: 14785 matches 14768
# Duplicate image: 14817 matches 14785
# Duplicate image: 14869 matches 14817
# Duplicate image: 14953 matches 14583
# Duplicate image: 15003 matches 14869
# Duplicate image: 15012 matches 15003
# Duplicate image: 15067 matches 15012
# Duplicate image: 15148 matches 8745
# Duplicate image: 15168 matches 15067
# Duplicate image: 15277 matches 1902
# Duplicate image: 15290 matches 15168
# Duplicate image: 15339 matches 3911
# Duplicate image: 15406 matches 15290
# Duplicate image: 15500 matches 4308
# Duplicate image: 15509 matches 4875
# Duplicate image: 15584 matches 12045
# Duplicate image: 15595 matches 14529
# Duplicate image: 15643 matches 1553
# Duplicate image: 15645 matches 15406
# Duplicate image: 15714 matches 228
# Duplicate image: 15818 matches 15059
# Duplicate image: 15822 matches 13532
# Duplicate image: 15835 matches 12846
# Duplicate image: 15914 matches 12965
# Duplicate image: 15918 matches 15645
# Duplicate image: 15932 matches 15918
# Duplicate image: 16006 matches 15932
# Duplicate image: 16050 matches 9454
# Duplicate image: 16092 matches 16006
# Duplicate image: 16106 matches 7416
# Duplicate image: 16131 matches 16092
# Duplicate image: 16135 matches 16131
# Duplicate image: 16412 matches 16135
# Duplicate image: 16439 matches 14451
# Duplicate image: 16448 matches 16412
# Duplicate image: 16478 matches 16448
# Duplicate image: 16520 matches 16478
# Duplicate image: 16695 matches 7582
# Duplicate image: 16699 matches 16520
# Duplicate image: 16734 matches 4285
# Duplicate image: 16740 matches 16699
# Duplicate image: 16741 matches 3920
# Duplicate image: 16780 matches 12875
# Duplicate image: 16818 matches 14763
# Duplicate image: 16823 matches 16740
# Duplicate image: 16835 matches 7278
# Duplicate image: 16838 matches 876
# Duplicate image: 16885 matches 16823
# Duplicate image: 16905 matches 6692
# Duplicate image: 16936 matches 12246
# Duplicate image: 16938 matches 11837
# Duplicate image: 16987 matches 16885
# Duplicate image: 17045 matches 16987
# Duplicate image: 17062 matches 5005
# Duplicate image: 17182 matches 17045
# Duplicate image: 17213 matches 17182
# Duplicate image: 17222 matches 17213
# Duplicate image: 17284 matches 17222
# Duplicate image: 17296 matches 6217
# Duplicate image: 17313 matches 12052
# Duplicate image: 17341 matches 17284
# Duplicate image: 17373 matches 17341
# Duplicate image: 17532 matches 6167
# Duplicate image: 17585 matches 15584
# Duplicate image: 17637 matches 13847
# Duplicate image: 17673 matches 17373
# Duplicate image: 17685 matches 17673
# Duplicate image: 17725 matches 17685
# Duplicate image: 17736 matches 7367
# Duplicate image: 17791 matches 17725
# Duplicate image: 17883 matches 5584
# Duplicate image: 17913 matches 17276
# Duplicate image: 17917 matches 17791
# Duplicate image: 17970 matches 17917
# Duplicate image: 18006 matches 8971
# Duplicate image: 18081 matches 10912
# Duplicate image: 18084 matches 15927
# Duplicate image: 18099 matches 17970
# Duplicate image: 18138 matches 18099
# Duplicate image: 18174 matches 13190
# Duplicate image: 18229 matches 18138
# Duplicate image: 18271 matches 18229
# Duplicate image: 18272 matches 10695
# Duplicate image: 18329 matches 1526
# Duplicate image: 18331 matches 10658
# Duplicate image: 18437 matches 17434
# Duplicate image: 18465 matches 18271
# Duplicate image: 18487 matches 18465
# Duplicate image: 18504 matches 18487
# Duplicate image: 18511 matches 18504
# Duplicate image: 18576 matches 14649
# Duplicate image: 18577 matches 18511
# Duplicate image: 18615 matches 5495
# Duplicate image: 18670 matches 18577
# Duplicate image: 18675 matches 18670
# Duplicate image: 18744 matches 11139
# Duplicate image: 18785 matches 13789
# Duplicate image: 18795 matches 18675
# Duplicate image: 18829 matches 18795
# Duplicate image: 18858 matches 18829
# Duplicate image: 18872 matches 13673
# Duplicate image: 19003 matches 6222
# Duplicate image: 19057 matches 14337
# Duplicate image: 19219 matches 18858
# Duplicate image: 19224 matches 10474
# Duplicate image: 19286 matches 19219
# Duplicate image: 19314 matches 10083
# Duplicate image: 19458 matches 19286
# Duplicate image: 19465 matches 19458
# Duplicate image: 19567 matches 19465
# Duplicate image: 19639 matches 6400
# Duplicate image: 19774 matches 19567
# Duplicate image: 19848 matches 19774
# Duplicate image: 19931 matches 18053
# Duplicate image: 19976 matches 19848
# Duplicate image: 19981 matches 8318
# Duplicate image: 20038 matches 152
# Duplicate image: 20040 matches 12911
# Duplicate image: 20092 matches 13917
# Duplicate image: 20094 matches 19976
# Duplicate image: 20161 matches 6416
# Duplicate image: 20248 matches 14189
# Duplicate image: 20343 matches 20094
# Duplicate image: 20364 matches 17585
# Duplicate image: 20438 matches 20343
# Duplicate image: 20452 matches 8626
# Duplicate image: 20508 matches 20438
# Duplicate image: 20672 matches 20508
# Duplicate image: 20688 matches 17623
# Duplicate image: 20848 matches 20672
# Duplicate image: 20914 matches 1031
# Duplicate image: 20977 matches 3511
# Duplicate image: 21002 matches 15014
# Duplicate image: 21010 matches 20848
# Duplicate image: 21031 matches 2614
# Duplicate image: 21052 matches 21010
# Duplicate image: 21104 matches 13233
# Duplicate image: 21123 matches 20830
# Duplicate image: 21178 matches 21052
# Duplicate image: 21181 matches 21178
# Duplicate image: 21182 matches 14495
# Duplicate image: 21184 matches 13334
# Duplicate image: 21252 matches 21181
# Duplicate image: 21280 matches 8581
# Duplicate image: 21348 matches 21252
# Duplicate image: 21352 matches 21348
# Duplicate image: 21374 matches 5645
# Duplicate image: 21428 matches 21352
# Duplicate image: 21433 matches 20773
# Duplicate image: 21437 matches 21428
# Duplicate image: 21577 matches 21437
# Duplicate image: 21632 matches 21577
# Duplicate image: 21643 matches 21632
# Duplicate image: 21716 matches 6455
# Duplicate image: 21740 matches 21643
# Duplicate image: 21750 matches 21740
# Duplicate image: 21826 matches 21750
# Duplicate image: 21861 matches 13263
# Duplicate image: 21866 matches 292
# Duplicate image: 21891 matches 18489
# Duplicate image: 21927 matches 21826
# Duplicate image: 21942 matches 21927
# Duplicate image: 21952 matches 20364
# Duplicate image: 21962 matches 21942
# Duplicate image: 21995 matches 5412
# Duplicate image: 22043 matches 21743
# Duplicate image: 22046 matches 12565
# Duplicate image: 22064 matches 13995
# Duplicate image: 22067 matches 12833
# Duplicate image: 22103 matches 21521
# Duplicate image: 22118 matches 2450
# Duplicate image: 22132 matches 9906
# Duplicate image: 22140 matches 19224
# Duplicate image: 22176 matches 8237
# Duplicate image: 22177 matches 21962
# Duplicate image: 22245 matches 10800
# Duplicate image: 22289 matches 22177
# Duplicate image: 22313 matches 22289
# Duplicate image: 22314 matches 12300
# Duplicate image: 22349 matches 2804
# Duplicate image: 22355 matches 9857
# Duplicate image: 22446 matches 17920
# Duplicate image: 22522 matches 22313
# Duplicate image: 22549 matches 22522
# Duplicate image: 22557 matches 7544
# Duplicate image: 22567 matches 728
# Duplicate image: 22569 matches 22549
# Duplicate image: 22616 matches 22569
# Duplicate image: 22628 matches 15796
# Duplicate image: 22851 matches 22616
# Duplicate image: 22874 matches 22851
# Duplicate image: 22921 matches 18782
# Duplicate image: 22993 matches 22874
# Duplicate image: 23042 matches 21860
# Duplicate image: 23076 matches 22993
# Duplicate image: 23104 matches 23076
# Duplicate image: 23116 matches 23104
# Duplicate image: 23143 matches 23116
# Duplicate image: 23177 matches 16471
# Duplicate image: 23328 matches 23143
# Duplicate image: 23352 matches 21952
# Duplicate image: 23390 matches 23328
# Duplicate image: 23417 matches 23390
# Duplicate image: 23436 matches 13314
# Duplicate image: 23470 matches 12281
# Duplicate image: 23483 matches 3547
# Duplicate image: 23485 matches 13243
# Duplicate image: 23495 matches 20171
# Duplicate image: 23598 matches 23417
# Duplicate image: 23627 matches 11681
# Duplicate image: 23634 matches 23598
# Duplicate image: 23701 matches 12006
# Duplicate image: 23722 matches 23634
# Duplicate image: 23766 matches 11291
# Duplicate image: 23895 matches 23722
# Duplicate image: 23897 matches 23895
# Duplicate image: 23961 matches 12000
# Duplicate image: 24091 matches 15379
# Duplicate image: 24136 matches 3221
# Duplicate image: 24216 matches 877
# Duplicate image: 24247 matches 17208
# Duplicate image: 24291 matches 23898
# Duplicate image: 24294 matches 23128
# Duplicate image: 24305 matches 11640
# Duplicate image: 24342 matches 23897
# Duplicate image: 24360 matches 7445
# Duplicate image: 24449 matches 24342
# Duplicate image: 24470 matches 24449
# Duplicate image: 24513 matches 1157
# Duplicate image: 24527 matches 7877
# Duplicate image: 24543 matches 10542
# Duplicate image: 24563 matches 23352
# Duplicate image: 24588 matches 24470
# Duplicate image: 24608 matches 24588
# Duplicate image: 24625 matches 19930
# Duplicate image: 24633 matches 24608
# Duplicate image: 24654 matches 24633
# Duplicate image: 24718 matches 24654
# Duplicate image: 24730 matches 19674
# Duplicate image: 24739 matches 24718
# Duplicate image: 24796 matches 19566
# Duplicate image: 24826 matches 21662
# Duplicate image: 24900 matches 9322
# Duplicate image: 25095 matches 23619
# Duplicate image: 25231 matches 4284
# Duplicate image: 25239 matches 15552
# Duplicate image: 25331 matches 24739
# Duplicate image: 25358 matches 25331
# Duplicate image: 25427 matches 13908
# Duplicate image: 25452 matches 17044
# Duplicate image: 25541 matches 25358
# Duplicate image: 25543 matches 8915
# Duplicate image: 25549 matches 25541
# Duplicate image: 25561 matches 25549
# Duplicate image: 25581 matches 25561
# Duplicate image: 25584 matches 12701
# Duplicate image: 25587 matches 17589
# Duplicate image: 25598 matches 12893
# Duplicate image: 25668 matches 22249
# Duplicate image: 25669 matches 25581
# Duplicate image: 25674 matches 25669
# Duplicate image: 25686 matches 25674
# Duplicate image: 25701 matches 25116
# Duplicate image: 25704 matches 25686
# Duplicate image: 25856 matches 25704
# Duplicate image: 25959 matches 15797
# Duplicate image: 25977 matches 22504
# Duplicate image: 25978 matches 658
# Duplicate image: 26089 matches 25856
# Duplicate image: 26096 matches 10220
# Duplicate image: 26125 matches 26089
# Duplicate image: 26195 matches 26125
# Duplicate image: 26248 matches 26195
# Duplicate image: 26284 matches 24716
# Duplicate image: 26317 matches 5758
# Duplicate image: 26322 matches 26248
# Duplicate image: 26349 matches 26322
# Duplicate image: 26392 matches 130
# Duplicate image: 26419 matches 26349
# Duplicate image: 26445 matches 26419
# Duplicate image: 26450 matches 13527
# Duplicate image: 26458 matches 4418
# Duplicate image: 26476 matches 26445
# Duplicate image: 26481 matches 26476
# Duplicate image: 26534 matches 26515
# Duplicate image: 26689 matches 26481
# Duplicate image: 26704 matches 4669
# Duplicate image: 26717 matches 10710
# Duplicate image: 26726 matches 26689
# Duplicate image: 26751 matches 20815
# Duplicate image: 26755 matches 4847
# Duplicate image: 26813 matches 26416
# Duplicate image: 26855 matches 15041
# Duplicate image: 26937 matches 26726
# Duplicate image: 26944 matches 4234
# Duplicate image: 26984 matches 26937
# Duplicate image: 27010 matches 26984
# Duplicate image: 27052 matches 1672
# Duplicate image: 27096 matches 20296
# Duplicate image: 27157 matches 19213
# Duplicate image: 27189 matches 21243
# Duplicate image: 27192 matches 27010
# Duplicate image: 27198 matches 27192
# Duplicate image: 27201 matches 27198
# Duplicate image: 27212 matches 27201
# Duplicate image: 27259 matches 27212
# Duplicate image: 27286 matches 27259
# Duplicate image: 27316 matches 8908
# Duplicate image: 27320 matches 17879
# Duplicate image: 27322 matches 27286
# Duplicate image: 27333 matches 27322
# Duplicate image: 27356 matches 26782
# Duplicate image: 27361 matches 27333
# Duplicate image: 27403 matches 12162
# Duplicate image: 27435 matches 27361
# Duplicate image: 27456 matches 27435
# Duplicate image: 27472 matches 27456
# Duplicate image: 27475 matches 27472
# Duplicate image: 27581 matches 6795
# Duplicate image: 27686 matches 27475
# Duplicate image: 27697 matches 27686
# Duplicate image: 27720 matches 24305
# Duplicate image: 27783 matches 27697
# Duplicate image: 27868 matches 27783
# Duplicate image: 27902 matches 27868
# Duplicate image: 28020 matches 22111
# Duplicate image: 28100 matches 27902
# Duplicate image: 28149 matches 28100
# Duplicate image: 28180 matches 17514
# Duplicate image: 28266 matches 19002
# Duplicate image: 28268 matches 28149
# Duplicate image: 28334 matches 10598
# Duplicate image: 28360 matches 15500
# Duplicate image: 28408 matches 7285
# Duplicate image: 28450 matches 23190
# Duplicate image: 28463 matches 7982
# Duplicate image: 28469 matches 15864
# Duplicate image: 28484 matches 15784
# Duplicate image: 28533 matches 28268
# Duplicate image: 28541 matches 27313
# Duplicate image: 28550 matches 11389
# Duplicate image: 28564 matches 8965
# Duplicate image: 28565 matches 12559
# Duplicate image: 28656 matches 11435
# Duplicate image: 28657 matches 28533
# Duplicate image: 28690 matches 23086
# Duplicate image: 28698 matches 28624
# Duplicate image: 28765 matches 28657
# Duplicate image: 28767 matches 28765
# Duplicate image: 28814 matches 11770
# Duplicate image: 28857 matches 19676
# Duplicate image: 28962 matches 28767
# Duplicate image: 28963 matches 8749
# Duplicate image: 28984 matches 28962
# Duplicate image: 29048 matches 26870
# Duplicate image: 29059 matches 28984
# Duplicate image: 29069 matches 2934
# Duplicate image: 29071 matches 24563
# Duplicate image: 29114 matches 42
# Duplicate image: 29116 matches 29059
# Duplicate image: 29118 matches 29116
# Duplicate image: 29218 matches 5984
# Duplicate image: 29233 matches 17321
# Duplicate image: 29242 matches 6035
# Duplicate image: 29364 matches 22170
# Duplicate image: 29370 matches 12685
# Duplicate image: 29393 matches 18998
# Duplicate image: 29503 matches 21855
# Duplicate image: 29524 matches 401
# Duplicate image: 29608 matches 29118
# Duplicate image: 29612 matches 10771
# Duplicate image: 29626 matches 29608
# Duplicate image: 29627 matches 23256
# Duplicate image: 29646 matches 22358
# Duplicate image: 29653 matches 28656
# Duplicate image: 29657 matches 29626
# Duplicate image: 29666 matches 4344
# Duplicate image: 29683 matches 29657
# Duplicate image: 29685 matches 3166
# Duplicate image: 29703 matches 1499
# Duplicate image: 29731 matches 29683
# Duplicate image: 29735 matches 19255
# Duplicate image: 29751 matches 26855
# Duplicate image: 29765 matches 29731
# Duplicate image: 29788 matches 11899
# Duplicate image: 29820 matches 29765
# Duplicate image: 29824 matches 29820
# Duplicate image: 29841 matches 10883
# Duplicate image: 29918 matches 15180
# Duplicate image: 29921 matches 29824
# Duplicate image: 30012 matches 29921
# Duplicate image: 30029 matches 29071
# Duplicate image: 30037 matches 30012
# Duplicate image: 30055 matches 24506
# Duplicate image: 30056 matches 6662
# Duplicate image: 30079 matches 16486
# Duplicate image: 30109 matches 29152
# Duplicate image: 30117 matches 20040
# Duplicate image: 30169 matches 7152
# Duplicate image: 30206 matches 22585
# Duplicate image: 30262 matches 7892
# Duplicate image: 30291 matches 30037
# Duplicate image: 30321 matches 19410
# Duplicate image: 30325 matches 22159
# Duplicate image: 30330 matches 8321
# Duplicate image: 30335 matches 23926
# Duplicate image: 30359 matches 18148
# Duplicate image: 30372 matches 12366
# Duplicate image: 30407 matches 30291
# Duplicate image: 30420 matches 28416
# Duplicate image: 30478 matches 22877
# Duplicate image: 30514 matches 30407
# Duplicate image: 30540 matches 30514
# Duplicate image: 30606 matches 30540
# Duplicate image: 30609 matches 15382
# Duplicate image: 30615 matches 20774
# Duplicate image: 30621 matches 25395
# Duplicate image: 30656 matches 30606
# Duplicate image: 30682 matches 10059
# Duplicate image: 30702 matches 15774
# Duplicate image: 30734 matches 30656
# Duplicate image: 30844 matches 19074
# Duplicate image: 30902 matches 30734
# Duplicate image: 30911 matches 13935
# Duplicate image: 30961 matches 10169
# Duplicate image: 30972 matches 21761
# Duplicate image: 31012 matches 30902
# Duplicate image: 31019 matches 30404
# Duplicate image: 31042 matches 19298
# Duplicate image: 31078 matches 27720
# Duplicate image: 31131 matches 31012
# Duplicate image: 31159 matches 17618
# Duplicate image: 31164 matches 7856
# Duplicate image: 31218 matches 22010
# Duplicate image: 31259 matches 8164
# Duplicate image: 31267 matches 31131
# Duplicate image: 31284 matches 18278
# Duplicate image: 31299 matches 17028
# Duplicate image: 31302 matches 2916
# Duplicate image: 31308 matches 20063
# Duplicate image: 31506 matches 24906
# Duplicate image: 31528 matches 31267
# Duplicate image: 31549 matches 9154
# Duplicate image: 31618 matches 31528
# Duplicate image: 31640 matches 30436
# Duplicate image: 31647 matches 31618
# Duplicate image: 31673 matches 2087
# Duplicate image: 31688 matches 17344
# Duplicate image: 31690 matches 31647
# Duplicate image: 31706 matches 546
# Duplicate image: 31727 matches 17979
# Duplicate image: 31755 matches 18462
# Duplicate image: 31811 matches 12228
# Duplicate image: 31824 matches 31690
# Duplicate image: 31825 matches 31824
# Duplicate image: 31853 matches 25855
# Duplicate image: 31889 matches 31825
# Duplicate image: 31892 matches 12099
# Duplicate image: 31904 matches 31889
# Duplicate image: 31922 matches 14959
# Duplicate image: 31979 matches 15111
# Duplicate image: 31989 matches 31904
# Duplicate image: 32046 matches 10936
# Duplicate image: 32086 matches 31989
# Duplicate image: 32143 matches 29597
# Duplicate image: 32145 matches 24218
# Duplicate image: 32324 matches 20228
# Duplicate image: 32329 matches 31171
# Duplicate image: 32339 matches 30267
# Duplicate image: 32343 matches 32086
# Duplicate image: 32346 matches 10827
# Duplicate image: 32544 matches 32343
# Duplicate image: 32546 matches 8693
# Duplicate image: 32610 matches 11701
# Duplicate image: 32633 matches 31464
# Duplicate image: 32675 matches 13491
# Duplicate image: 32717 matches 4742
# Duplicate image: 32741 matches 14146
# Duplicate image: 32792 matches 2598
# Duplicate image: 32800 matches 32544
# Duplicate image: 32807 matches 32800
# Duplicate image: 32840 matches 21012
# Duplicate image: 32850 matches 22093
# Duplicate image: 32862 matches 32807
# Duplicate image: 32879 matches 8399
# Duplicate image: 32881 matches 13596
# Duplicate image: 32919 matches 8355
# Duplicate image: 32936 matches 17302
# Duplicate image: 32952 matches 32862
# Duplicate image: 33011 matches 18540
# Duplicate image: 33012 matches 24711
# Duplicate image: 33059 matches 32339
# Duplicate image: 33081 matches 32955
# Duplicate image: 33201 matches 32952
# Duplicate image: 33237 matches 33201
# Duplicate image: 33286 matches 30029
# Duplicate image: 33298 matches 33237
# Duplicate image: 33299 matches 33298
# Duplicate image: 33308 matches 822
# Duplicate image: 33329 matches 30117
# Duplicate image: 33331 matches 3333
# Duplicate image: 33360 matches 23231
# Duplicate image: 33362 matches 11894
# Duplicate image: 33366 matches 5404
# Duplicate image: 33370 matches 26084
# Duplicate image: 33373 matches 33299
# Duplicate image: 33383 matches 1950
# Duplicate image: 33404 matches 33373
# Duplicate image: 33406 matches 6539
# Duplicate image: 33428 matches 33404
# Duplicate image: 33434 matches 3412
# Duplicate image: 33452 matches 25239
# Duplicate image: 33472 matches 33428
# Duplicate image: 33481 matches 31078
# Duplicate image: 33534 matches 5997
# Duplicate image: 33554 matches 33472
# Duplicate image: 33580 matches 9961
# Duplicate image: 33606 matches 13901
# Duplicate image: 33610 matches 33554
# Duplicate image: 33682 matches 33610
# Duplicate image: 33701 matches 33682
# Duplicate image: 33723 matches 27176
# Duplicate image: 33742 matches 20257
# Duplicate image: 33777 matches 26137
# Duplicate image: 33783 matches 33701
# Duplicate image: 33789 matches 33783
# Duplicate image: 33813 matches 1229
# Duplicate image: 33870 matches 5542
# Duplicate image: 33948 matches 33789
# Duplicate image: 33956 matches 5731
# Duplicate image: 33966 matches 30832
# Duplicate image: 33967 matches 31307
# Duplicate image: 34002 matches 11890
# Duplicate image: 34019 matches 26447
# Duplicate image: 34047 matches 14846
# Duplicate image: 34133 matches 33948
# Duplicate image: 34234 matches 34133
# Duplicate image: 34306 matches 13437
# Duplicate image: 34307 matches 11433
# Duplicate image: 34326 matches 4186
# Duplicate image: 34355 matches 4638
# Duplicate image: 34361 matches 3128
# Duplicate image: 34370 matches 32610
# Duplicate image: 34373 matches 7046
# Duplicate image: 34383 matches 28649
# Duplicate image: 34503 matches 10850
# Duplicate image: 34510 matches 33967
# Duplicate image: 34559 matches 18084
# Duplicate image: 34717 matches 28068
# Duplicate image: 34771 matches 34234
# Duplicate image: 34779 matches 7569
# Duplicate image: 34822 matches 34771
# Duplicate image: 34825 matches 34822
# Duplicate image: 34853 matches 23470
# Duplicate image: 34900 matches 30090
# Duplicate image: 34906 matches 2284
# Duplicate image: 34951 matches 1979
# Duplicate image: 34959 matches 3092
# Duplicate image: 34988 matches 34889
# Duplicate image: 35004 matches 34825
# Duplicate image: 35013 matches 23436
# Duplicate image: 35019 matches 748
# Duplicate image: 35039 matches 9846
# Duplicate image: 35040 matches 8670
# Duplicate image: 35084 matches 12940
# Duplicate image: 35092 matches 35004
# Duplicate image: 35135 matches 15742
# Duplicate image: 35137 matches 30094
# Duplicate image: 35142 matches 1056
# Duplicate image: 35150 matches 887
# Duplicate image: 35232 matches 22777
# Duplicate image: 35277 matches 2250
# Duplicate image: 35281 matches 28089
# Duplicate image: 35297 matches 35092
# Duplicate image: 35315 matches 34088
# Duplicate image: 35316 matches 35297
# Duplicate image: 35417 matches 15339
# Duplicate image: 35436 matches 15980
# Duplicate image: 35441 matches 9120
# Duplicate image: 35495 matches 29069
# Duplicate image: 35530 matches 21061
# Duplicate image: 35580 matches 14018
# Duplicate image: 35596 matches 32169
# Duplicate image: 35601 matches 35316
# Duplicate image: 35613 matches 33329
# Duplicate image: 35629 matches 31943
# Duplicate image: 35642 matches 34559
# Duplicate image: 35643 matches 2753
# Duplicate image: 35681 matches 35417
# Duplicate image: 35695 matches 14466
# Duplicate image: 35703 matches 13630
# Duplicate image: 35788 matches 9569
# Duplicate image: 35833 matches 34960
# Duplicate image: 35877 matches 30478
# Duplicate image: 35879 matches 35601
# Duplicate image: 35970 matches 22043
# Duplicate image: 35990 matches 3138
# Duplicate image: 36157 matches 23771
# Duplicate image: 36158 matches 23973
# Duplicate image: 36181 matches 377
# Duplicate image: 36198 matches 27418
# Duplicate image: 36267 matches 35879
# Duplicate image: 36269 matches 33362
# Duplicate image: 36272 matches 9416
# Duplicate image: 36276 matches 13119
# Duplicate image: 36311 matches 36267
# Duplicate image: 36326 matches 11555
# Duplicate image: 36336 matches 36311
# Duplicate image: 36457 matches 36336
# Duplicate image: 36471 matches 36457
# Duplicate image: 36519 matches 29659
# Duplicate image: 36548 matches 16228
# Duplicate image: 36564 matches 27996
# Duplicate image: 36590 matches 36471
# Duplicate image: 36650 matches 36590
# Duplicate image: 36720 matches 29505
# Duplicate image: 36729 matches 3402
# Duplicate image: 36738 matches 12075
# Duplicate image: 36793 matches 23455
# Duplicate image: 36801 matches 33481
# Duplicate image: 36815 matches 35349
# Duplicate image: 36822 matches 21744
# Duplicate image: 36843 matches 36650
# Duplicate image: 36880 matches 36843
# Duplicate image: 36893 matches 34370
# Duplicate image: 36896 matches 29252
# Duplicate image: 36960 matches 36880
# Duplicate image: 36990 matches 36801
# Duplicate image: 37051 matches 2685
# Duplicate image: 37075 matches 6724
# Duplicate image: 37085 matches 18401
# Duplicate image: 37121 matches 36960
# Duplicate image: 37177 matches 13079
# Duplicate image: 37212 matches 5778
# Duplicate image: 37229 matches 5323
# Duplicate image: 37295 matches 22864
# Duplicate image: 37307 matches 20372
# Duplicate image: 37358 matches 22952
# Duplicate image: 37380 matches 37121
# Duplicate image: 37388 matches 12395
# Duplicate image: 37430 matches 12589
# Duplicate image: 37443 matches 37380
# Duplicate image: 37444 matches 37443
# Duplicate image: 37477 matches 17151
# Duplicate image: 37568 matches 26844
# Duplicate image: 37574 matches 37444
# Duplicate image: 37622 matches 36658
# Duplicate image: 37646 matches 37574
# Duplicate image: 37657 matches 23042
# Duplicate image: 37668 matches 35101
# Duplicate image: 37670 matches 7509
# Duplicate image: 37765 matches 37646
# Duplicate image: 37835 matches 26511
# Duplicate image: 37847 matches 28165
# Duplicate image: 37870 matches 34186
# Duplicate image: 37894 matches 37765
# Duplicate image: 37912 matches 33121
# Duplicate image: 37947 matches 3476
# Duplicate image: 38000 matches 4938
# Duplicate image: 38025 matches 16560
# Duplicate image: 38052 matches 10754
# Duplicate image: 38076 matches 13218
# Duplicate image: 38118 matches 5381
# Duplicate image: 38143 matches 19145
# Duplicate image: 38160 matches 37894
# Duplicate image: 38176 matches 25121
# Duplicate image: 38220 matches 32738
# Duplicate image: 38253 matches 38160
# Duplicate image: 38297 matches 19449
# Duplicate image: 38319 matches 28861
# Duplicate image: 38343 matches 9325
# Duplicate image: 38420 matches 38253
# Duplicate image: 38435 matches 20247
# Duplicate image: 38470 matches 16607
# Duplicate image: 38537 matches 38420
# Duplicate image: 38542 matches 4940
# Duplicate image: 38552 matches 36701
# Duplicate image: 38553 matches 34111
# Duplicate image: 38569 matches 6791
# Duplicate image: 38587 matches 29829
# Duplicate image: 38613 matches 38537
# Duplicate image: 38616 matches 17391
# Duplicate image: 38640 matches 10332
# Duplicate image: 38657 matches 38613
# Duplicate image: 38658 matches 38657
# Duplicate image: 38675 matches 19783
# Duplicate image: 38690 matches 38658
# Duplicate image: 38708 matches 38690
# Duplicate image: 38734 matches 18539
# Duplicate image: 38745 matches 35681
# Duplicate image: 38771 matches 30721
# Duplicate image: 38778 matches 9637
# Duplicate image: 38791 matches 38708
# Duplicate image: 38815 matches 18644
# Duplicate image: 38821 matches 38791
# Duplicate image: 38833 matches 26284
# Duplicate image: 38862 matches 2401
# Duplicate image: 38878 matches 7495
# Duplicate image: 38881 matches 38821
# Duplicate image: 38921 matches 35864
# Duplicate image: 39047 matches 13183
# Duplicate image: 39056 matches 38881
# Duplicate image: 39079 matches 32547
# Duplicate image: 39138 matches 18955
# Duplicate image: 39187 matches 2214
# Duplicate image: 39221 matches 102
# Duplicate image: 39244 matches 13542
# Duplicate image: 39387 matches 4438
# Duplicate image: 39406 matches 21630
# Duplicate image: 39425 matches 6271
# Duplicate image: 39442 matches 39056
# Duplicate image: 39493 matches 3600
# Duplicate image: 39520 matches 23333
# Duplicate image: 39524 matches 39442
# Duplicate image: 39525 matches 39524
# Duplicate image: 39551 matches 5683
# Duplicate image: 39582 matches 39525
# Duplicate image: 39651 matches 8368
# Duplicate image: 39716 matches 2072
# Duplicate image: 39764 matches 27005
# Duplicate image: 39796 matches 9588
# Duplicate image: 39834 matches 31979
# Duplicate image: 39843 matches 39582
# Duplicate image: 39910 matches 11631
# Duplicate image: 39975 matches 26534
# Duplicate image: 39980 matches 31174
# Duplicate image: 39981 matches 39843
# Duplicate image: 40014 matches 1518
# Duplicate image: 40042 matches 18527
# Duplicate image: 40090 matches 7096
# Duplicate image: 40094 matches 24256
# Duplicate image: 40098 matches 8139
# Duplicate image: 40112 matches 39981
# Duplicate image: 40126 matches 40112
# Duplicate image: 40145 matches 11016
# Duplicate image: 40174 matches 31733
# Duplicate image: 40402 matches 27621
# Duplicate image: 40429 matches 39054
# Duplicate image: 40431 matches 13921
# Duplicate image: 40459 matches 37670
# Duplicate image: 40471 matches 5690
# Duplicate image: 40476 matches 28999
# Duplicate image: 40498 matches 38031
# Duplicate image: 40533 matches 40126
# Duplicate image: 40584 matches 40533
# Duplicate image: 40611 matches 16738
# Duplicate image: 40623 matches 33286
# Duplicate image: 40688 matches 5560
# Duplicate image: 40691 matches 40584
# Duplicate image: 40712 matches 40691
# Duplicate image: 40768 matches 29573
# Duplicate image: 40784 matches 18074
# Duplicate image: 40785 matches 5116
# Duplicate image: 40804 matches 29800
# Duplicate image: 40839 matches 5417
# Duplicate image: 40878 matches 40712
# Duplicate image: 40910 matches 40878
# Duplicate image: 40920 matches 35277
# Duplicate image: 40963 matches 39305
# Duplicate image: 40987 matches 40910
# Duplicate image: 41052 matches 15034
# Duplicate image: 41054 matches 10693
# Duplicate image: 41078 matches 5859
# Duplicate image: 41088 matches 20423
# Duplicate image: 41119 matches 40987
# Duplicate image: 41156 matches 41119
# Duplicate image: 41170 matches 4843
# Duplicate image: 41202 matches 23485
# Duplicate image: 41217 matches 41156
# Duplicate image: 41218 matches 41217
# Duplicate image: 41253 matches 41218
# Duplicate image: 41277 matches 41253
# Duplicate image: 41294 matches 24481
# Duplicate image: 41312 matches 27679
# Duplicate image: 41314 matches 41277
# Duplicate image: 41450 matches 21059
# Duplicate image: 41461 matches 26347
# Duplicate image: 41465 matches 6708
# Duplicate image: 41509 matches 14338
# Duplicate image: 41519 matches 17411
# Duplicate image: 41526 matches 41314
# Duplicate image: 41561 matches 41526
# Duplicate image: 41567 matches 19039
# Duplicate image: 41618 matches 11204
# Duplicate image: 41635 matches 41561
# Duplicate image: 41652 matches 38342
# Duplicate image: 41739 matches 1921
# Duplicate image: 41754 matches 23744
# Duplicate image: 41812 matches 41635
# Duplicate image: 41816 matches 16582
# Duplicate image: 41858 matches 16345
# Duplicate image: 41867 matches 18616
# Duplicate image: 41920 matches 41812
# Duplicate image: 41924 matches 18006
# Duplicate image: 41940 matches 33818
# Duplicate image: 41950 matches 41920
# Duplicate image: 42031 matches 41950
# Duplicate image: 42065 matches 24775
# Duplicate image: 42069 matches 29610
# Duplicate image: 42142 matches 42031
# Duplicate image: 42150 matches 13656
# Duplicate image: 42187 matches 21292
# Duplicate image: 42195 matches 24208
# Duplicate image: 42200 matches 10890
# Duplicate image: 42240 matches 26863
# Duplicate image: 42272 matches 24521
# Duplicate image: 42287 matches 11371
# Duplicate image: 42310 matches 28711
# Duplicate image: 42311 matches 34421
# Duplicate image: 42321 matches 21513
# Duplicate image: 42324 matches 780
# Duplicate image: 42343 matches 32487
# Duplicate image: 42347 matches 42142
# Duplicate image: 42360 matches 42347
# Duplicate image: 42397 matches 39888
# Duplicate image: 42410 matches 42360
# Duplicate image: 42438 matches 12929
# Duplicate image: 42471 matches 42410
# Duplicate image: 42486 matches 42471
# Duplicate image: 42492 matches 42486
# Duplicate image: 42522 matches 24083
# Duplicate image: 42525 matches 16479
# Duplicate image: 42606 matches 42492
# Duplicate image: 42609 matches 24291
# Duplicate image: 42631 matches 42606
# Duplicate image: 42637 matches 30765
# Duplicate image: 42639 matches 24112
# Duplicate image: 42696 matches 26561
# Duplicate image: 42711 matches 4854
# Duplicate image: 42760 matches 15157
# Duplicate image: 42776 matches 34368
# Duplicate image: 42830 matches 42631
# Duplicate image: 42865 matches 19541
# Duplicate image: 42888 matches 35754
# Duplicate image: 42893 matches 42830
# Duplicate image: 42916 matches 42893
# Duplicate image: 42943 matches 9170
# Duplicate image: 42946 matches 34317
# Duplicate image: 43008 matches 1643
# Duplicate image: 43018 matches 10172
# Duplicate image: 43032 matches 32123
# Duplicate image: 43049 matches 18741
# Duplicate image: 43057 matches 35057
# Duplicate image: 43077 matches 40623
# Duplicate image: 43092 matches 20645
# Duplicate image: 43108 matches 7331
# Duplicate image: 43114 matches 16432
# Duplicate image: 43128 matches 24007
# Duplicate image: 43174 matches 3709
# Duplicate image: 43184 matches 35673
# Duplicate image: 43212 matches 35642
# Duplicate image: 43242 matches 14604
# Duplicate image: 43259 matches 28428
# Duplicate image: 43260 matches 42916
# Duplicate image: 43276 matches 43260
# Duplicate image: 43375 matches 43276
# Duplicate image: 43381 matches 43375
# Duplicate image: 43415 matches 14543
# Duplicate image: 43441 matches 35933
# Duplicate image: 43446 matches 39904
# Duplicate image: 43457 matches 15879
# Duplicate image: 43473 matches 43381
# Duplicate image: 43497 matches 43473
# Duplicate image: 43498 matches 12887
# Duplicate image: 43570 matches 37811
# Duplicate image: 43584 matches 39450
# Duplicate image: 43613 matches 16544
# Duplicate image: 43641 matches 32743
# Duplicate image: 43643 matches 10416
# Duplicate image: 43673 matches 18781
# Duplicate image: 43704 matches 34324
# Duplicate image: 43754 matches 16381
# Duplicate image: 43783 matches 43497
# Duplicate image: 43805 matches 36269
# Duplicate image: 43806 matches 43783
# Duplicate image: 43815 matches 43806
# Duplicate image: 43832 matches 17677
# Duplicate image: 43872 matches 18421
# Duplicate image: 43876 matches 43815
# Duplicate image: 43893 matches 24418
# Duplicate image: 43895 matches 9426
# Duplicate image: 43915 matches 43876
# Duplicate image: 43955 matches 5946
# Duplicate image: 43971 matches 10994
# Duplicate image: 43976 matches 43915
# Duplicate image: 44008 matches 12174
# Duplicate image: 44009 matches 39834
# Duplicate image: 44019 matches 43976
# Duplicate image: 44040 matches 29406
# Duplicate image: 44068 matches 1711
# Duplicate image: 44078 matches 26428
# Duplicate image: 44081 matches 4054
# Duplicate image: 44089 matches 44019
# Duplicate image: 44126 matches 13249
# Duplicate image: 44132 matches 44089
# Duplicate image: 44133 matches 38199
# Duplicate image: 44175 matches 26096
# Duplicate image: 44255 matches 44132
# Duplicate image: 44269 matches 44255
# Duplicate image: 44322 matches 44269
# Duplicate image: 44418 matches 7271
# Duplicate image: 44438 matches 44322
# Duplicate image: 44458 matches 17205
# Duplicate image: 44467 matches 27805
# Duplicate image: 44493 matches 17296
# Duplicate image: 44523 matches 14112
# Duplicate image: 44528 matches 26794
# Duplicate image: 44542 matches 19513
# Duplicate image: 44548 matches 43077
# Duplicate image: 44555 matches 9537
# Duplicate image: 44641 matches 20411
# Duplicate image: 44644 matches 26887
# Duplicate image: 44658 matches 43415
# Duplicate image: 44710 matches 44438
# Duplicate image: 44729 matches 24513
# Duplicate image: 44734 matches 35281
# Duplicate image: 44804 matches 661
# Duplicate image: 44807 matches 35340
# Duplicate image: 44825 matches 38145
# Duplicate image: 44840 matches 17082
# Duplicate image: 44845 matches 44710
# Duplicate image: 44889 matches 44845
# Duplicate image: 44891 matches 11156
# Duplicate image: 44928 matches 44889
# Duplicate image: 44966 matches 29532
# Duplicate image: 44979 matches 44928
# Duplicate image: 45035 matches 14664
# Duplicate image: 45065 matches 38129
# Duplicate image: 45066 matches 44979
# Duplicate image: 45086 matches 35613
# Duplicate image: 45182 matches 1430
# Duplicate image: 45228 matches 14405
# Duplicate image: 45257 matches 9965
# Duplicate image: 45279 matches 11673
# Duplicate image: 45286 matches 43743
# Duplicate image: 45291 matches 11786
# Duplicate image: 45404 matches 21014
# Duplicate image: 45418 matches 25623
# Duplicate image: 45437 matches 40134
# Duplicate image: 45451 matches 4031
# Duplicate image: 45454 matches 45066
# Duplicate image: 45468 matches 45093
# Duplicate image: 45496 matches 12611
# Duplicate image: 45508 matches 27001
# Duplicate image: 45511 matches 17123
# Duplicate image: 45513 matches 23166
# Duplicate image: 45526 matches 10365
# Duplicate image: 45579 matches 41390
# Duplicate image: 45602 matches 45454
# Duplicate image: 45621 matches 45602
# Duplicate image: 45669 matches 14947
# Duplicate image: 45698 matches 35017
# Duplicate image: 45767 matches 34450
# Duplicate image: 45782 matches 45621
# Duplicate image: 45856 matches 44195
# Duplicate image: 45857 matches 27900
# Duplicate image: 45858 matches 4870
# Duplicate image: 45887 matches 16774
# Duplicate image: 45930 matches 25587
# Duplicate image: 45937 matches 14482
# Duplicate image: 45952 matches 1027
# Duplicate image: 45957 matches 40214
# Duplicate image: 45990 matches 44548
# Duplicate image: 46013 matches 30192
# Duplicate image: 46038 matches 35841
# Duplicate image: 46048 matches 27654
# Duplicate image: 46065 matches 45782
# Duplicate image: 46198 matches 46065
# Duplicate image: 46201 matches 31683
# Duplicate image: 46246 matches 16628
# Duplicate image: 46252 matches 36893
# Duplicate image: 46259 matches 19394
# Duplicate image: 46304 matches 17139
# Duplicate image: 46384 matches 46198
# Duplicate image: 46415 matches 18551
# Duplicate image: 46438 matches 41715
# Duplicate image: 46451 matches 46384
# Duplicate image: 46508 matches 23550
# Duplicate image: 46523 matches 19934
# Duplicate image: 46554 matches 26817
# Duplicate image: 46589 matches 46451
# Duplicate image: 46621 matches 46589
# Duplicate image: 46656 matches 12026
# Duplicate image: 46668 matches 2514
# Duplicate image: 46697 matches 43654
# Duplicate image: 46706 matches 46621
# Duplicate image: 46711 matches 145
# Duplicate image: 46719 matches 15655
# Duplicate image: 46723 matches 46706
# Duplicate image: 46737 matches 36844
# Duplicate image: 46746 matches 21884
# Duplicate image: 46756 matches 46723
# Duplicate image: 46775 matches 675
# Duplicate image: 46787 matches 19771
# Duplicate image: 46803 matches 27442
# Duplicate image: 46805 matches 38862
# Duplicate image: 46825 matches 29612
# Duplicate image: 46854 matches 22808
# Duplicate image: 46877 matches 30368
# Duplicate image: 46957 matches 46756
# Duplicate image: 46963 matches 45990
# Duplicate image: 46977 matches 46957
# Duplicate image: 46992 matches 1438
# Duplicate image: 47000 matches 45806
# Duplicate image: 47002 matches 30547
# Duplicate image: 47019 matches 14701
# Duplicate image: 47057 matches 46825
# Duplicate image: 47059 matches 28154
# Duplicate image: 47066 matches 40454
# Duplicate image: 47077 matches 46977
# Duplicate image: 47085 matches 45082
# Duplicate image: 47090 matches 45660
# Duplicate image: 47171 matches 44717
# Duplicate image: 47202 matches 47077
# Duplicate image: 47285 matches 47202
# Duplicate image: 47288 matches 21173
# Duplicate image: 47401 matches 47285
# Duplicate image: 47415 matches 47401
# Duplicate image: 47426 matches 13336
# Duplicate image: 47439 matches 35019
# Duplicate image: 47511 matches 24150
# Duplicate image: 47539 matches 14737
# Duplicate image: 47610 matches 28699
# Duplicate image: 47629 matches 40504
# Duplicate image: 47639 matches 40592
# Duplicate image: 47666 matches 46252
# Duplicate image: 47686 matches 47415
# Duplicate image: 47713 matches 2486
# Duplicate image: 47714 matches 47686
# Duplicate image: 47729 matches 45596
# Duplicate image: 47732 matches 37365
# Duplicate image: 47777 matches 18433
# Duplicate image: 47796 matches 18121
# Duplicate image: 47807 matches 47714
# Duplicate image: 47808 matches 13752
# Duplicate image: 47832 matches 47807
# Duplicate image: 47834 matches 46299
# Duplicate image: 47835 matches 40672
# Duplicate image: 47837 matches 21564
# Duplicate image: 47841 matches 32006
# Duplicate image: 47847 matches 47832
# Duplicate image: 47852 matches 47847
# Duplicate image: 47854 matches 36990
# Duplicate image: 47868 matches 47852
# Duplicate image: 47902 matches 21421
# Duplicate image: 47910 matches 30658
# Duplicate image: 47933 matches 38707
# Duplicate image: 47961 matches 22705
# Duplicate image: 47985 matches 26165
# Duplicate image: 48089 matches 45086
# Duplicate image: 48102 matches 41854
# Duplicate image: 48105 matches 18486
# Duplicate image: 48108 matches 47868
# Duplicate image: 48131 matches 47057
# ...
# Test image 6875 is in the training set
# Test image 6877 is in the training set
# Test image 6880 is in the training set
# Test image 6883 is in the training set
# Test image 6900 is in the training set
# Test image 6904 is in the training set
# Test image 6956 is in the training set
# Test image 6959 is in the training set
# Test image 6968 is in the training set
# Test image 6978 is in the training set
# Test image 6981 is in the training set
# Test image 6987 is in the training set
# Test image 7006 is in the training set
# Test image 7025 is in the training set
# Test image 7030 is in the training set
# Test image 7036 is in the training set
# Test image 7043 is in the training set
# Test image 7047 is in the training set
# Test image 7054 is in the training set
# Test image 7060 is in the training set
# Test image 7069 is in the training set
# Test image 7094 is in the training set
# Test image 7097 is in the training set
# Test image 7102 is in the training set
# Test image 7104 is in the training set
# Test image 7106 is in the training set
# Test image 7107 is in the training set
# Test image 7109 is in the training set
# Test image 7115 is in the training set
# Test image 7133 is in the training set
# Test image 7139 is in the training set
# Test image 7146 is in the training set
# Test image 7150 is in the training set
# Test image 7152 is in the training set
# Test image 7153 is in the training set
# Test image 7156 is in the training set
# Test image 7163 is in the training set
# Test image 7173 is in the training set
# Test image 7176 is in the training set
# Test image 7187 is in the training set
# Test image 7203 is in the training set
# Test image 7206 is in the training set
# Test image 7207 is in the training set
# Test image 7233 is in the training set
# Test image 7235 is in the training set
# Test image 7238 is in the training set
# Test image 7245 is in the training set
# Test image 7249 is in the training set
# Test image 7251 is in the training set
# Test image 7259 is in the training set
# Test image 7261 is in the training set
# Test image 7280 is in the training set
# Test image 7285 is in the training set
# Test image 7306 is in the training set
# Test image 7323 is in the training set
# Test image 7332 is in the training set
# Test image 7334 is in the training set
# Test image 7339 is in the training set
# Test image 7343 is in the training set
# Test image 7346 is in the training set
# Test image 7349 is in the training set
# Test image 7354 is in the training set
# Test image 7367 is in the training set
# Test image 7382 is in the training set
# Test image 7384 is in the training set
# Test image 7392 is in the training set
# Test image 7395 is in the training set
# Test image 7424 is in the training set
# Test image 7425 is in the training set
# Test image 7437 is in the training set
# Test image 7460 is in the training set
# Test image 7463 is in the training set
# Test image 7476 is in the training set
# Test image 7495 is in the training set
# Test image 7509 is in the training set
# Test image 7515 is in the training set
# Test image 7518 is in the training set
# Test image 7526 is in the training set
# Test image 7532 is in the training set
# Test image 7533 is in the training set
# Test image 7565 is in the training set
# Test image 7577 is in the training set
# Test image 7584 is in the training set
# Test image 7598 is in the training set
# Test image 7616 is in the training set
# Test image 7618 is in the training set
# Test image 7620 is in the training set
# Test image 7621 is in the training set
# Test image 7622 is in the training set
# Test image 7625 is in the training set
# Test image 7626 is in the training set
# Test image 7652 is in the training set
# Test image 7663 is in the training set
# Test image 7674 is in the training set
# Test image 7677 is in the training set
# Test image 7678 is in the training set
# Test image 7681 is in the training set
# Test image 7687 is in the training set
# Test image 7702 is in the training set
# Test image 7711 is in the training set
# Test image 7713 is in the training set
# Test image 7744 is in the training set
# Test image 7745 is in the training set
# Test image 7746 is in the training set
# Test image 7767 is in the training set
# Test image 7770 is in the training set
# Test image 7778 is in the training set
# Test image 7782 is in the training set
# Test image 7786 is in the training set
# Test image 7797 is in the training set
# Test image 7803 is in the training set
# Test image 7804 is in the training set
# Test image 7806 is in the training set
# Test image 7811 is in the training set
# Test image 7831 is in the training set
# Test image 7833 is in the training set
# Test image 7839 is in the training set
# Test image 7846 is in the training set
# Test image 7853 is in the training set
# Test image 7865 is in the training set
# Test image 7878 is in the training set
# Test image 7890 is in the training set
# Test image 7910 is in the training set
# Test image 7930 is in the training set
# Test image 7931 is in the training set
# Test image 7932 is in the training set
# Test image 7938 is in the training set
# Test image 7950 is in the training set
# Test image 7971 is in the training set
# Test image 7972 is in the training set
# Test image 7992 is in the training set
# Test image 7995 is in the training set
# Test image 7999 is in the training set
# Test image 8004 is in the training set
# Test image 8012 is in the training set
# Test image 8015 is in the training set
# Test image 8020 is in the training set
# Test image 8037 is in the training set
# Test image 8046 is in the training set
# Test image 8055 is in the training set
# Test image 8058 is in the training set
# Test image 8064 is in the training set
# Test image 8067 is in the training set
# Test image 8069 is in the training set
# Test image 8070 is in the training set
# Test image 8078 is in the training set
# Test image 8079 is in the training set
# Test image 8090 is in the training set
# Test image 8115 is in the training set
# Test image 8145 is in the training set
# Test image 8168 is in the training set
# Test image 8170 is in the training set
# Test image 8177 is in the training set
# Test image 8183 is in the training set
# Test image 8194 is in the training set
# Test image 8198 is in the training set
# Test image 8203 is in the training set
# Test image 8212 is in the training set
# Test image 8215 is in the training set
# Test image 8227 is in the training set
# Test image 8256 is in the training set
# Test image 8261 is in the training set
# Test image 8270 is in the training set
# Test image 8273 is in the training set
# Test image 8280 is in the training set
# Test image 8285 is in the training set
# Test image 8288 is in the training set
# Test image 8292 is in the training set
# Test image 8301 is in the training set
# Test image 8320 is in the training set
# Test image 8322 is in the training set
# Test image 8324 is in the training set
# Test image 8329 is in the training set
# Test image 8357 is in the training set
# Test image 8363 is in the training set
# Test image 8369 is in the training set
# Test image 8371 is in the training set
# Test image 8373 is in the training set
# Test image 8388 is in the training set
# Test image 8405 is in the training set
# Test image 8412 is in the training set
# Test image 8421 is in the training set
# Test image 8431 is in the training set
# Test image 8437 is in the training set
# Test image 8478 is in the training set
# Test image 8483 is in the training set
# Test image 8494 is in the training set
# Test image 8495 is in the training set
# Test image 8501 is in the training set
# Test image 8503 is in the training set
# Test image 8506 is in the training set
# Test image 8511 is in the training set
# Test image 8513 is in the training set
# Test image 8515 is in the training set
# Test image 8529 is in the training set
# Test image 8539 is in the training set
# Test image 8541 is in the training set
# Test image 8546 is in the training set
# Test image 8551 is in the training set
# Test image 8557 is in the training set
# Test image 8565 is in the training set
# Test image 8582 is in the training set
# Test image 8587 is in the training set
# Test image 8603 is in the training set
# Test image 8605 is in the training set
# Test image 8610 is in the training set
# Test image 8611 is in the training set
# Test image 8623 is in the training set
# Test image 8626 is in the training set
# Test image 8632 is in the training set
# Test image 8634 is in the training set
# Test image 8639 is in the training set
# Test image 8641 is in the training set
# Test image 8642 is in the training set
# Test image 8667 is in the training set
# Test image 8669 is in the training set
# Test image 8670 is in the training set
# Test image 8674 is in the training set
# Test image 8679 is in the training set
# Test image 8686 is in the training set
# Test image 8689 is in the training set
# Test image 8690 is in the training set
# Test image 8698 is in the training set
# Test image 8699 is in the training set
# Test image 8706 is in the training set
# Test image 8734 is in the training set
# Test image 8745 is in the training set
# Test image 8747 is in the training set
# Test image 8749 is in the training set
# Test image 8763 is in the training set
# Test image 8781 is in the training set
# Test image 8783 is in the training set
# Test image 8788 is in the training set
# Test image 8790 is in the training set
# Test image 8796 is in the training set
# Test image 8803 is in the training set
# Test image 8804 is in the training set
# Test image 8808 is in the training set
# Test image 8819 is in the training set
# Test image 8821 is in the training set
# Test image 8829 is in the training set
# Test image 8830 is in the training set
# Test image 8843 is in the training set
# Test image 8845 is in the training set
# Test image 8851 is in the training set
# Test image 8861 is in the training set
# Test image 8871 is in the training set
# Test image 8894 is in the training set
# Test image 8901 is in the training set
# Test image 8902 is in the training set
# Test image 8908 is in the training set
# Test image 8913 is in the training set
# Test image 8914 is in the training set
# Test image 8919 is in the training set
# Test image 8920 is in the training set
# Test image 8924 is in the training set
# Test image 8927 is in the training set
# Test image 8930 is in the training set
# Test image 8936 is in the training set
# Test image 8937 is in the training set
# Test image 8942 is in the training set
# Test image 8956 is in the training set
# Test image 8973 is in the training set
# Test image 8978 is in the training set
# Test image 8983 is in the training set
# Test image 8986 is in the training set
# Test image 8990 is in the training set
# Test image 9009 is in the training set
# Test image 9010 is in the training set
# Test image 9013 is in the training set
# Test image 9027 is in the training set
# Test image 9038 is in the training set
# Test image 9050 is in the training set
# Test image 9051 is in the training set
# Test image 9052 is in the training set
# Test image 9062 is in the training set
# Test image 9068 is in the training set
# Test image 9085 is in the training set
# Test image 9111 is in the training set
# Test image 9114 is in the training set
# Test image 9117 is in the training set
# Test image 9141 is in the training set
# Test image 9165 is in the training set
# Test image 9191 is in the training set
# Test image 9192 is in the training set
# Test image 9206 is in the training set
# Test image 9208 is in the training set
# Test image 9217 is in the training set
# Test image 9219 is in the training set
# Test image 9229 is in the training set
# Test image 9239 is in the training set
# Test image 9243 is in the training set
# Test image 9244 is in the training set
# Test image 9250 is in the training set
# Test image 9253 is in the training set
# Test image 9254 is in the training set
# Test image 9265 is in the training set
# Test image 9267 is in the training set
# Test image 9268 is in the training set
# Test image 9276 is in the training set
# Test image 9282 is in the training set
# Test image 9295 is in the training set
# Test image 9300 is in the training set
# Test image 9308 is in the training set
# Test image 9309 is in the training set
# Test image 9321 is in the training set
# Test image 9326 is in the training set
# Test image 9331 is in the training set
# Test image 9333 is in the training set
# Test image 9334 is in the training set
# Test image 9348 is in the training set
# Test image 9349 is in the training set
# Test image 9359 is in the training set
# Test image 9366 is in the training set
# Test image 9367 is in the training set
# Test image 9372 is in the training set
# Test image 9375 is in the training set
# Test image 9378 is in the training set
# Test image 9384 is in the training set
# Test image 9389 is in the training set
# Test image 9390 is in the training set
# Test image 9391 is in the training set
# Test image 9394 is in the training set
# Test image 9400 is in the training set
# Test image 9401 is in the training set
# Test image 9403 is in the training set
# Test image 9407 is in the training set
# Test image 9410 is in the training set
# Test image 9411 is in the training set
# Test image 9417 is in the training set
# Test image 9441 is in the training set
# Test image 9443 is in the training set
# Test image 9448 is in the training set
# Test image 9453 is in the training set
# Test image 9456 is in the training set
# Test image 9457 is in the training set
# Test image 9461 is in the training set
# Test image 9466 is in the training set
# Test image 9468 is in the training set
# Test image 9480 is in the training set
# Test image 9485 is in the training set
# Test image 9501 is in the training set
# Test image 9506 is in the training set
# Test image 9526 is in the training set
# Test image 9527 is in the training set
# Test image 9547 is in the training set
# Test image 9557 is in the training set
# Test image 9564 is in the training set
# Test image 9565 is in the training set
# Test image 9566 is in the training set
# Test image 9572 is in the training set
# Test image 9579 is in the training set
# Test image 9588 is in the training set
# Test image 9592 is in the training set
# Test image 9600 is in the training set
# Test image 9602 is in the training set
# Test image 9620 is in the training set
# Test image 9624 is in the training set
# Test image 9627 is in the training set
# Test image 9644 is in the training set
# Test image 9658 is in the training set
# Test image 9661 is in the training set
# Test image 9675 is in the training set
# Test image 9678 is in the training set
# Test image 9682 is in the training set
# Test image 9692 is in the training set
# Test image 9693 is in the training set
# Test image 9701 is in the training set
# Test image 9708 is in the training set
# Test image 9709 is in the training set
# Test image 9711 is in the training set
# Test image 9719 is in the training set
# Test image 9738 is in the training set
# Test image 9741 is in the training set
# Test image 9754 is in the training set
# Test image 9764 is in the training set
# Test image 9789 is in the training set
# Test image 9791 is in the training set
# Test image 9793 is in the training set
# Test image 9800 is in the training set
# Test image 9806 is in the training set
# Test image 9807 is in the training set
# Test image 9812 is in the training set
# Test image 9816 is in the training set
# Test image 9822 is in the training set
# Test image 9829 is in the training set
# Test image 9856 is in the training set
# Test image 9859 is in the training set
# Test image 9860 is in the training set
# Test image 9864 is in the training set
# Test image 9868 is in the training set
# Test image 9869 is in the training set
# Test image 9874 is in the training set
# Test image 9876 is in the training set
# Test image 9881 is in the training set
# Test image 9888 is in the training set
# Test image 9898 is in the training set
# Test image 9899 is in the training set
# Test image 9905 is in the training set
# Test image 9913 is in the training set
# Test image 9920 is in the training set
# Test image 9925 is in the training set
# Test image 9939 is in the training set
# Test image 9940 is in the training set
# Test image 9954 is in the training set
# Test image 9959 is in the training set
# Test image 9965 is in the training set
# Test image 9982 is in the training set
# Test image 9993 is in the training set
# Test image 9995 is in the training set

# %% [markdown]
# ---
# Problem 6
# ---------
#
# Let's get an idea of what an off-the-shelf classifier can give you on this data. It's always good to check that there is something to learn, and that it's a problem that is not so trivial that a canned solution solves it.
#
# Train a simple model on this data using 50, 100, 1000 and 5000 training samples. Hint: you can use the LogisticRegression model from sklearn.linear_model.
#
# Optional question: train an off-the-shelf model on all the data!
#
# ---

# %%
# Train
trainer = LogisticRegression()

n_samples = 5000

img_size = train_dataset[0, :, :].shape[0]
X = np.reshape(train_dataset[0 : n_samples, :, :], [n_samples, img_size * img_size])
y = train_labels[0 : n_samples]

trainer.fit(X, y)

# Verify predictions
X_test = np.reshape(test_dataset[0 : n_samples, :, :], [n_samples, img_size * img_size])
y_test = test_labels[0 : n_samples]

score = trainer.score(X_test, y_test)
print ("Test score with %d samples: %.3f" % (n_samples, score))
# Out:
# Test score with 5000 samples: 0.849
